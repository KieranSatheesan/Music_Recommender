# %%
from dotenv import load_dotenv
import os

load_dotenv()
cid = os.getenv("SPOTIFY_CLIENT_ID")
sec = os.getenv("SPOTIFY_CLIENT_SECRET")
print(cid, sec)
# Out:
# 1fa818aab54945d0a82dc4d764a2f976 7db601d7a75140a7a72674695ef35b0b
