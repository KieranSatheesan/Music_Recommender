# %%
from pathlib import Path
import zipfile

ZIP_PATH = Path(r"C:\Users\Kiera\Downloads\archive (3).zip")

with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    all_files = z.namelist()
    
print(f"Total entries in ZIP: {len(all_files)}")
print("First 50 entries:")
for f in all_files[:50]:
    print(" ", f)
# Out:
# Total entries in ZIP: 1010
# First 50 entries:
#   README.md
#   data/mpd.slice.0-999.json
#   data/mpd.slice.1000-1999.json
#   data/mpd.slice.10000-10999.json
#   data/mpd.slice.100000-100999.json
#   data/mpd.slice.101000-101999.json
#   data/mpd.slice.102000-102999.json
#   data/mpd.slice.103000-103999.json
#   data/mpd.slice.104000-104999.json
#   data/mpd.slice.105000-105999.json
#   data/mpd.slice.106000-106999.json
#   data/mpd.slice.107000-107999.json
#   data/mpd.slice.108000-108999.json
#   data/mpd.slice.109000-109999.json
#   data/mpd.slice.11000-11999.json
#   data/mpd.slice.110000-110999.json
#   data/mpd.slice.111000-111999.json
#   data/mpd.slice.112000-112999.json
#   data/mpd.slice.113000-113999.json
#   data/mpd.slice.114000-114999.json
#   data/mpd.slice.115000-115999.json
#   data/mpd.slice.116000-116999.json
#   data/mpd.slice.117000-117999.json
#   data/mpd.slice.118000-118999.json
#   data/mpd.slice.119000-119999.json
#   data/mpd.slice.12000-12999.json
#   data/mpd.slice.120000-120999.json
#   data/mpd.slice.121000-121999.json
#   data/mpd.slice.122000-122999.json
#   data/mpd.slice.123000-123999.json
#   data/mpd.slice.124000-124999.json
#   data/mpd.slice.125000-125999.json
#   data/mpd.slice.126000-126999.json
#   data/mpd.slice.127000-127999.json
#   data/mpd.slice.128000-128999.json
#   data/mpd.slice.129000-129999.json
#   data/mpd.slice.13000-13999.json
#   data/mpd.slice.130000-130999.json
#   data/mpd.slice.131000-131999.json
#   data/mpd.slice.132000-132999.json
#   data/mpd.slice.133000-133999.json
#   data/mpd.slice.134000-134999.json
#   data/mpd.slice.135000-135999.json
#   data/mpd.slice.136000-136999.json
#   data/mpd.slice.137000-137999.json
#   data/mpd.slice.138000-138999.json
#   data/mpd.slice.139000-139999.json
#   data/mpd.slice.14000-14999.json
#   data/mpd.slice.140000-140999.json
#   data/mpd.slice.141000-141999.json

# %%
from pathlib import Path
import zipfile
import shutil

PROJECT_ROOT = Path("..").resolve()
DATA_RAW = PROJECT_ROOT / "data" / "raw"
MPD_DIR = DATA_RAW / "mpd"
ZIP_PATH = Path(r"C:\Users\Kiera\Downloads\archive (3).zip")

print("Project root:", PROJECT_ROOT)
print("MPD target dir:", MPD_DIR)
print("Zip file:", ZIP_PATH)

# Clean mpd dir again just to be sure
if MPD_DIR.exists():
    print("Deleting existing MPD directory...")
    shutil.rmtree(MPD_DIR)
MPD_DIR.mkdir(parents=True, exist_ok=True)
print("Created clean MPD directory:", MPD_DIR)

with zipfile.ZipFile(ZIP_PATH, 'r') as z:
    all_files = sorted(z.namelist())
    print(f"Total entries in ZIP: {len(all_files)}")

    # Match any path that *contains* "mpd.slice." and ends with .json
    slice_files = [f for f in all_files if "mpd.slice." in f and f.endswith(".json")]
    print(f"Total slice-like files in ZIP: {len(slice_files)}")

    # Take first 100 by path sort order
    files_to_extract = slice_files[:100]
    print(f"Extracting {len(files_to_extract)} slices...\n")

    for filename in files_to_extract:
        print("Extracting:", filename)
        # Extract into MPD_DIR, stripping any folder structure
        z.extract(filename, MPD_DIR)

print("\nDone extracting candidate slices.")

# Sanity check
extracted_files = sorted(MPD_DIR.rglob("mpd.slice.*.json"))
print(f"\nFound {len(extracted_files)} mpd.slice JSON files under {MPD_DIR}")
for f in extracted_files[:10]:
    print(" ", f.relative_to(MPD_DIR))
# Out:
# Project root: C:\Users\Kiera\Music_Recommender
# MPD target dir: C:\Users\Kiera\Music_Recommender\data\raw\mpd
# Zip file: C:\Users\Kiera\Downloads\archive (3).zip
# Deleting existing MPD directory...
# Created clean MPD directory: C:\Users\Kiera\Music_Recommender\data\raw\mpd
# Total entries in ZIP: 1010
# Total slice-like files in ZIP: 1000
# Extracting 100 slices...
#
# Extracting: data/mpd.slice.0-999.json
# Extracting: data/mpd.slice.1000-1999.json
# Extracting: data/mpd.slice.10000-10999.json
# Extracting: data/mpd.slice.100000-100999.json
# Extracting: data/mpd.slice.101000-101999.json
# Extracting: data/mpd.slice.102000-102999.json
# Extracting: data/mpd.slice.103000-103999.json
# Extracting: data/mpd.slice.104000-104999.json
# Extracting: data/mpd.slice.105000-105999.json
# Extracting: data/mpd.slice.106000-106999.json
# Extracting: data/mpd.slice.107000-107999.json
# Extracting: data/mpd.slice.108000-108999.json
# Extracting: data/mpd.slice.109000-109999.json
# Extracting: data/mpd.slice.11000-11999.json
# Extracting: data/mpd.slice.110000-110999.json
# Extracting: data/mpd.slice.111000-111999.json
# Extracting: data/mpd.slice.112000-112999.json
# Extracting: data/mpd.slice.113000-113999.json
# Extracting: data/mpd.slice.114000-114999.json
# Extracting: data/mpd.slice.115000-115999.json
# Extracting: data/mpd.slice.116000-116999.json
# Extracting: data/mpd.slice.117000-117999.json
# Extracting: data/mpd.slice.118000-118999.json
# Extracting: data/mpd.slice.119000-119999.json
# Extracting: data/mpd.slice.12000-12999.json
# Extracting: data/mpd.slice.120000-120999.json
# Extracting: data/mpd.slice.121000-121999.json
# Extracting: data/mpd.slice.122000-122999.json
# Extracting: data/mpd.slice.123000-123999.json
# Extracting: data/mpd.slice.124000-124999.json
# Extracting: data/mpd.slice.125000-125999.json
# Extracting: data/mpd.slice.126000-126999.json
# Extracting: data/mpd.slice.127000-127999.json
# Extracting: data/mpd.slice.128000-128999.json
# Extracting: data/mpd.slice.129000-129999.json
# Extracting: data/mpd.slice.13000-13999.json
# Extracting: data/mpd.slice.130000-130999.json
# Extracting: data/mpd.slice.131000-131999.json
# Extracting: data/mpd.slice.132000-132999.json
# Extracting: data/mpd.slice.133000-133999.json
# Extracting: data/mpd.slice.134000-134999.json
# Extracting: data/mpd.slice.135000-135999.json
# Extracting: data/mpd.slice.136000-136999.json
# Extracting: data/mpd.slice.137000-137999.json
# Extracting: data/mpd.slice.138000-138999.json
# Extracting: data/mpd.slice.139000-139999.json
# Extracting: data/mpd.slice.14000-14999.json
# Extracting: data/mpd.slice.140000-140999.json
# Extracting: data/mpd.slice.141000-141999.json
# Extracting: data/mpd.slice.142000-142999.json
# Extracting: data/mpd.slice.143000-143999.json
# Extracting: data/mpd.slice.144000-144999.json
# Extracting: data/mpd.slice.145000-145999.json
# Extracting: data/mpd.slice.146000-146999.json
# Extracting: data/mpd.slice.147000-147999.json
# Extracting: data/mpd.slice.148000-148999.json
# Extracting: data/mpd.slice.149000-149999.json
# Extracting: data/mpd.slice.15000-15999.json
# Extracting: data/mpd.slice.150000-150999.json
# Extracting: data/mpd.slice.151000-151999.json
# Extracting: data/mpd.slice.152000-152999.json
# Extracting: data/mpd.slice.153000-153999.json
# Extracting: data/mpd.slice.154000-154999.json
# Extracting: data/mpd.slice.155000-155999.json
# Extracting: data/mpd.slice.156000-156999.json
# Extracting: data/mpd.slice.157000-157999.json
# Extracting: data/mpd.slice.158000-158999.json
# Extracting: data/mpd.slice.159000-159999.json
# Extracting: data/mpd.slice.16000-16999.json
# Extracting: data/mpd.slice.160000-160999.json
# Extracting: data/mpd.slice.161000-161999.json
# Extracting: data/mpd.slice.162000-162999.json
# Extracting: data/mpd.slice.163000-163999.json
# Extracting: data/mpd.slice.164000-164999.json
# Extracting: data/mpd.slice.165000-165999.json
# Extracting: data/mpd.slice.166000-166999.json
# Extracting: data/mpd.slice.167000-167999.json
# Extracting: data/mpd.slice.168000-168999.json
# Extracting: data/mpd.slice.169000-169999.json
# Extracting: data/mpd.slice.17000-17999.json
# Extracting: data/mpd.slice.170000-170999.json
# Extracting: data/mpd.slice.171000-171999.json
# Extracting: data/mpd.slice.172000-172999.json
# Extracting: data/mpd.slice.173000-173999.json
# Extracting: data/mpd.slice.174000-174999.json
# Extracting: data/mpd.slice.175000-175999.json
# Extracting: data/mpd.slice.176000-176999.json
# Extracting: data/mpd.slice.177000-177999.json
# Extracting: data/mpd.slice.178000-178999.json
# Extracting: data/mpd.slice.179000-179999.json
# Extracting: data/mpd.slice.18000-18999.json
# Extracting: data/mpd.slice.180000-180999.json
# Extracting: data/mpd.slice.181000-181999.json
# Extracting: data/mpd.slice.182000-182999.json
# Extracting: data/mpd.slice.183000-183999.json
# Extracting: data/mpd.slice.184000-184999.json
# Extracting: data/mpd.slice.185000-185999.json
# Extracting: data/mpd.slice.186000-186999.json
# Extracting: data/mpd.slice.187000-187999.json
# Extracting: data/mpd.slice.188000-188999.json
#
# Done extracting candidate slices.
#
# Found 100 mpd.slice JSON files under C:\Users\Kiera\Music_Recommender\data\raw\mpd
#   data\mpd.slice.0-999.json
#   data\mpd.slice.1000-1999.json
#   data\mpd.slice.10000-10999.json
#   data\mpd.slice.100000-100999.json
#   data\mpd.slice.101000-101999.json
#   data\mpd.slice.102000-102999.json
#   data\mpd.slice.103000-103999.json
#   data\mpd.slice.104000-104999.json
#   data\mpd.slice.105000-105999.json
#   data\mpd.slice.106000-106999.json
